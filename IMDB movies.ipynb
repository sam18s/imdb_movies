# %% [markdown]
# # IMDB Movies Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count   1000.000000      1000                     1000
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A group of intergalactic criminals are forced ...  Ridley Scott
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # Fill missing values

# %%
df['Revenue (Millions)'].fillna(df['Revenue (Millions)'].mean(), inplace=True)

# %%
df.dropna(subset=['Metascore'], inplace = True)

# %%
df.shape
# Out:
# (936, 12)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # Checking Data Accuracy and Missing Values

# %%
df_accuracy = df.dtypes
df_accuracy
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# # Check duplicate data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Visualization by Year

# %%
df['Year'].value_counts()
# Out:
# Year
# 2016    268
# 2015    123
# 2014     95
# 2013     86
# 2012     62
# 2010     59
# 2011     58
# 2008     49
# 2009     49
# 2007     46
# 2006     41
# Name: count, dtype: int64

# %%
from matplotlib import style
style.use('ggplot')

# %%
movie = df['Year'].value_counts().sort_index()

plt.figure(figsize=(16,9))
plt.plot(movie.index,movie.values, color='m', marker='o',markerfacecolor ='r' ,linestyle='-.')
plt.title("No of Movies by Year")
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.show()

# %%
ax = sns.countplot(data=df,x= 'Year')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Top Movies Genre

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Action,Adventure,Sci-Fi    50
# Drama                      43
# Comedy,Drama,Romance       32
# Comedy                     30
# Drama,Romance              28
#                            ..
# Action,Crime,Fantasy        1
# Comedy,Mystery              1
# Adventure,Comedy,Horror     1
# Comedy,Fantasy,Romance      1
# Comedy,Family,Fantasy       1
# Name: count, Length: 200, dtype: int64

# %%
# Assuming df is your DataFrame containing a column 'Genre' with comma-separated values
# Splitting the 'Genre' column by commas and creating a new DataFrame
df_genre = df['Genre'].str.split(',')

# Exploding the list-like column to separate each genre into its own row
df_genre = df_genre.explode()

# Counting the occurrences of each genre after exploding the data
df_genre.value_counts()
# Out:
# Genre
# Drama        474
# Action       289
# Comedy       268
# Adventure    249
# Thriller     183
# Crime        141
# Romance      131
# Sci-Fi       114
# Horror       108
# Mystery       99
# Fantasy       98
# Biography     71
# Family        50
# Animation     46
# History       28
# Music         16
# Sport         16
# War           12
# Western        6
# Musical        5
# Name: count, dtype: int64

# %%
# Assuming df_genre contains your data
plt.figure(figsize=(16, 9))

# Assuming df_genre is a pandas Series or DataFrame column
genre = df_genre.value_counts().sort_index()

# Create a horizontal bar plot using Seaborn
sns.barplot(y=genre.index, x=genre.values, palette='bright')
plt.title("Movie Genres")
plt.xlabel("Number of movies")
plt.ylabel("Genres")
plt.show()

# %%
# Create a figure and set its size using figsize
plt.figure(figsize=(16, 20))

# Create a pie chart using the 'genre' data with autopct='%1.1f%%' to display percentages on the chart
plt.pie(genre, autopct='%.1f')

# Set the title of the pie chart
plt.title("Movies by Genre")

# Display the pie chart
plt.show()

# %% [markdown]
# # TOP 10 high Movies by Votes and Revenue

# %%
votes = df['Votes'].max()
votes
# Out:
# 1791916

# %%
# Sort the DataFrame by 'Votes' column in descending order and retrieve the top 10 rows
top_10_movies = df.nlargest(10, 'Votes')

# Display the top 10 movies based on votes
top_10_movies[['Title', 'Votes']]
# Out:
#                      Title    Votes
# 54         The Dark Knight  1791916
# 80               Inception  1583625
# 124  The Dark Knight Rises  1222645
# 36            Interstellar  1047747
# 76            The Avengers  1045588
# 144       Django Unchained  1039115
# 77    Inglourious Basterds   959065
# 99            The Departed   937414
# 87                  Avatar   935408
# 64            The Prestige   913152

# %%
# Create a bar plot using seaborn: 'Title' on the y-axis and 'Votes' on the x-axis
sns.barplot(y=top_10_movies['Title'], x=top_10_movies['Votes'])

# Set the title of the plot
plt.title("Top 10 Movies by Votes")

# Display the plot
plt.show()

# %%
# Sort the DataFrame by 'Revenue (Millions)' column in descending order and retrieve the top 10 rows
top_10_movies_byrevenue = df.nlargest(10, 'Revenue (Millions)')

# Display the top 10 movies based on votes
top_10_movies_byrevenue[['Title', 'Revenue (Millions)']]
# Out:
#                                           Title  Revenue (Millions)
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 87                                       Avatar              760.51
# 85                               Jurassic World              652.18
# 76                                 The Avengers              623.28
# 54                              The Dark Knight              533.32
# 12                                    Rogue One              532.17
# 119                                Finding Dory              486.29
# 94                      Avengers: Age of Ultron              458.99
# 124                       The Dark Knight Rises              448.13
# 578             The Hunger Games: Catching Fire              424.65

# %%
# Create a bar plot using seaborn: 'Title' on the y-axis and 'Revenue' on the x-axis
sns.barplot(y=top_10_movies_byrevenue['Title'], x=top_10_movies_byrevenue['Revenue (Millions)'],palette="Set2")

# Set the title of the plot
plt.title("Top 10 Movies by Revenue (Millions)")

# Display the plot
plt.show()

# %% [markdown]
# # Movies Rating on Histogram

# %%
# df['Rating'].value_counts()

# %%
# Create a histogram of the 'Rating' column from the DataFrame
plt.hist(df['Rating'], bins = 20, edgecolor='white',color = 'c')

# Set title and labels
plt.title("Rating of movies")
plt.xlabel("Rating")
plt.ylabel("No. of Ratings")

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))  

# Creating the boxplot
plt.boxplot(df['Rating'])

# Set title and labels
plt.title("Boxplot of Movie Ratings")
plt.xlabel("Rating")
plt.ylabel("Values")

# Display the plot
plt.show()

# %%
# Sort the DataFrame by 'Rating' to get titles with the highest ratings
top_rated_movies = df.sort_values(by='Rating', ascending=False)[['Title', 'Rating']].head(10)

# Display the top 10 movies with the highest ratings
top_rated_movies
# Out:
#                      Title  Rating
# 54         The Dark Knight     9.0
# 80               Inception     8.8
# 36            Interstellar     8.6
# 249       The Intouchables     8.6
# 96           Kimi no na wa     8.6
# 133               Whiplash     8.5
# 99            The Departed     8.5
# 124  The Dark Knight Rises     8.5
# 476    The Lives of Others     8.5
# 991       Taare Zameen Par     8.5

# %%
# adding different color on palette
custom_palette = ['red', 'orangered', 'orange', 'gold', 'forestgreen', 'greenyellow', 'aqua', 'm', 'deeppink', 'hotpink']

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))  # Set the figure size
sns.barplot(x='Rating', y='Title', data=top_rated_movies, palette=custom_palette)

# Set the labels and title
plt.xlabel('Rating')
plt.ylabel('Movie Title')
plt.title('Top 10 Movies with the Highest Ratings')

# Show the plot
plt.show()

# %%
# df['Runtime (Minutes)'].max()

# %% [markdown]
# # Which Year was High Revenue

# %%
revenue_by_year = df.groupby('Year')['Revenue (Millions)'].mean()
revenue_by_year
# Out:
# Year
# 2006     87.255610
# 2007     92.634190
# 2008     97.228089
# 2009    113.065623
# 2010    104.331572
# 2011     93.518041
# 2012    110.103065
# 2013     87.965381
# 2014     85.381503
# 2015     80.979506
# 2016     62.720285
# Name: Revenue (Millions), dtype: float64

# %%
# Set the figure size 
plt.figure(figsize=(10, 6))

# Create a bar plot using Seaborn: 'Year' on the x-axis and 'Revenue (Millions)' on the y-axis
sns.barplot(x=df['Year'], y=df['Revenue (Millions)'])

# Display the plot
plt.show()

# %%
# Assuming revenue_by_year is your DataFrame
ax = revenue_by_year.plot(kind='bar',color = 'orange')

# Set title and label 
plt.title("Revenue by year")
plt.ylabel('Revenue (Millions)')

plt.show()

# %% [markdown]
# # Top 10 Runtime Movies

# %%
# Sort the DataFrame by 'Runtime (Minutes)' in descending order and select the top 10 rows
top_10 = df.sort_values(by='Runtime (Minutes)', ascending=False).head(10)

# Keep only the columns 'Title' and 'Runtime (Minutes)', set 'Title' as the index
top_10 = top_10[['Title', 'Runtime (Minutes)']].set_index('Title')

# Display the resulting DataFrame showing the top 10 movies by runtime
top_10
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# La vie d'Adèle                                          180
# The Wolf of Wall Street                                 180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# The Hobbit: An Unexpected Journey                       169
# Pirates of the Caribbean: At World's End                169
# Interstellar                                            169
# The Curious Case of Benjamin Button                     166
# Australia                                               165

# %%
# Assuming top_10 is a DataFrame with 'Title' as the index and 'Runtime (Minutes)' as the column

# Create a horizontal bar plot using Matplotlib: 'Runtime (Minutes)' and 'Title'
ax = top_10.plot(kind='barh', color='mediumaquamarine', edgecolor='white')

# Display the plot
plt.show()

# %% [markdown]
# # Top 10 Actor

# %%
# Split the 'Actors' column by commas and remove spaces before or after each name
actr_name = df['Actors'].str.split(",").apply(lambda x: [i.strip() for i in x])

# Explode the list-like column to separate each actor name into its own row
actr_name = actr_name.explode()

# Count the occurrences of each actor name
top_10_actors = actr_name.value_counts().head(10)

# Display only the top 10 actors and their occurrence counts
top_10_actors
# Out:
# Actors
# Mark Wahlberg         15
# Hugh Jackman          14
# Christian Bale        13
# Brad Pitt             13
# Anne Hathaway         12
# Michael Fassbender    12
# Robert Downey Jr.     12
# Scarlett Johansson    12
# Tom Hardy             11
# Seth Rogen            11
# Name: count, dtype: int64

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(9, 6))  # Set the figure size
sns.barplot(x=top_10_actors.values, y=top_10_actors.index, palette='viridis')

# Set the labels and title
plt.xlabel('Occurrences')
plt.ylabel('Actor Name')
plt.title('Top 10 Actors by Occurrence Count')

# Show the plot
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Metascore'], df['Revenue (Millions)'], color='deeppink', marker='*', s=100, alpha=0.6)

# Adding labels and title
plt.title('Relationship between Metascore and Revenue')
plt.xlabel('Metascore')
plt.ylabel('Revenue (Millions)')

# Show the plot
plt.show()

# %% [markdown]
# # Top 10 Directors

# %%
df_d = df['Director'].value_counts().head(10)
df_d
# Out:
# Director
# Ridley Scott          8
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# David Yates           6
# David Fincher         5
# Antoine Fuqua         5
# Denis Villeneuve      5
# Woody Allen           5
# Danny Boyle           5
# Name: count, dtype: int64

# %%
sns.barplot(x=df_d.values,y=df_d.index)
plt.show()

# %% [markdown]
# # Heatmap of Movies Rating over Years

# %%
# Replace 'Year' with the appropriate column name if needed
heatmap_data = df.groupby(['Rating', 'Year']).size().unstack().fillna(0)

# Extract top 10 rating by movie count
top_directors = df['Rating'].value_counts().head(10).index

# Filter the heatmap data for top 10 directors
heatmap_data = heatmap_data.loc[top_directors]

plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size

# Create the heatmap
sns.heatmap(heatmap_data)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Rating')
plt.title('Number of Movies Rating over Years')

# Show plot
plt.show()
